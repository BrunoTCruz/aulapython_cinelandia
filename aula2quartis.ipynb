# %%
#importação de bibliotecas sempre no inicio
import pandas as pd
import numpy as np #usado para conceitos Estatisticos

# %%
# === 1) Carregar base ===
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep=';')
df['nada a ver'] = df['registro_ocorrencias'] + df['fase'] #resulta a soma das duas colunas
df
#print (df.head(6))
#print (df.descibre())
#print (df.tail(6))
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36898   159   10  2025  2025m10    35     4  Cachoeiras de Macacu  3300803
# 36899   165   10  2025  2025m10    33     5           Mangaratiba  3302601
# 36900   166   10  2025  2025m10    33     5        Angra dos Reis  3300100
# 36901   167   10  2025  2025m10    43     5                Paraty  3303807
# 36902   168   10  2025  2025m10    28     5             Rio Claro  3304409
#
# ...

# %%
df_roubo_celular_dp = df.groupby('cisp')['roubo_celular'].sum().reset_index()
df_roubo_celular_dp =  df_roubo_celular_dp.sort_values(by='roubo_celular', ascending = False)
print(df_roubo_celular_dp)
# Out:
#      cisp  roubo_celular
# 52     59          13788
# 57     64          10421
# 30     34           9379
# 25     29           8807
# 2       5           7992
# ..    ...            ...
# 94    111              2
# 129   155              1
# 126   152              1
# 131   157              1
# 77     92              0
#
# [138 rows x 2 columns]

# %%
array_roubo_celular = np.array(array_roubo_celular['Valor de Venda']) #criação do Array

# %%
#a Boa pratica sempre trabalha com esses valores de porcentagem nos quantis. Caso seja solicitado a alteração desses valores, 
#documentar de quem partiu a solicitação pois irá maquear os dados resultantes.

media = np.mean(array_roubo_celular)
mediana = np.median(array_roubo_celular)
q1 = np.quantile(array_roubo_celular, 0.25)
q2 = np.quantile(array_roubo_celular, 0.50)
q3 = np.quantile(array_roubo_celular, 0.75)

iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 + (1.5 * iqr)

print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
print(f'o valor do limite Superior é: {limite_superior}')
print(f'o valor do limite Inferior é: {limite_inferior}')

# %%
outliers_roubo_celular = df.roubo.celular.loc['furto_celular'] > limite_superior]

# %%
reg_met = ["Rio de Janeiro", "Niterói", "São Gonçalo", "Duque de Caxias", "Nova Iguaçu", "Belford Roxo", "São João de Meriti", "Nilópolis", "Mesquita", "Queimados", "Japeri", "Paracambi"]
df_capital = df.loc[df['munic'].isin (reg_met)]
df_capital['veiculo'] = df_capital['furto_veiculos'] + df_capital['roubo_veiculo']
df_capital
# Out:
# C:\Users\bruno.tcruz\AppData\Local\Temp\ipykernel_18384\1948486649.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_capital['veiculo'] = df_capital['furto_veiculos'] + df_capital['roubo_veiculo']
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...             ...      ...
# ...

# %%
df_veiculo_capital = df_capital.groupby('cisp')['veiculo'].sum().reset_index()
df_veiculo_capital =  df_veiculo_capital.sort_values(by='veiculo', ascending = False)
df_veiculo_capital
# Out:
#     cisp  veiculo
# 50    59    51285
# 55    64    43261
# 23    27    39024
# 30    34    36897
# 31    35    33436
# ..   ...      ...
# 54    63     1853
# 9     13     1488
# 42    51      803
# 7     11      181
# 41    45       78
#
# [65 rows x 2 columns]

# %%
array_veiculo_capital= np.array(df_veiculo_capital['veiculo']) #criação do Array

# %%
media = np.mean(array_veiculo_capital)
mediana = np.median(array_veiculo_capital)
q1 = np.quantile(array_veiculo_capital, 0.25)
q2 = np.quantile(array_veiculo_capital, 0.50)
q3 = np.quantile(array_veiculo_capital, 0.75)
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr) 
limite_inferior = q1 + (1.5 * iqr)
print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
print(f'o valor do limite Superior é: {limite_superior}')
print(f'o valor do limite Inferior é: {limite_inferior}')
# Out:
# A média é 13949.333333333334
# A mediana é 12701.0
# Primeiro quartil (Q1): 5015.25
# Segundo quartil (Q2, Mediana): 12701.0
# Terceiro quartil (Q3): 18068.75
# o valor do limite Superior é: 37649.0
# o valor do limite Inferior é: 24595.5

# %%
outliers_veiculo_capital = df_veiculo_capital[outliers_veiculo_capital]
#outliers_veiculo_capital = (df_veiculo_capital[veiculo] < limite_inferior) | (df_veiculo_capital[veiculo] > limite_superior)
df_veiculo_capital[outliers_veiculo_capital]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 #outliers_veiculo_capital = df_veiculo_capital[outliers_veiculo_capital]
#       2 #outliers_veiculo_capital = (df_veiculo_capital[veiculo] < limite_inferior) | (df_veiculo_capital[veiculo] > limite_superior)
# ----> 3 df_veiculo_capital[outliers_veiculo_capital]
#
# NameError: name 'outliers_veiculo_capital' is not defined

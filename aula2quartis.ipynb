# %%
#importação de bibliotecas sempre no inicio
import pandas as pd
import numpy as np #usado para conceitos Estatisticos

# %%
# === 1) Carregar base ===
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep=';', encoding='latin1')

print (df.head(6))
#print (df.descibre())
#print (df.tail(6))

# %%
df_roubo_celular_dp = df.groupby('cisp')['roubo_celular'].sum().reset_index()
df_roubo_celular_dp =  df_roubo_celular_dp.sort_values(by='roubo_celular', ascending = False)
print(df_roubo_celular_dp)
# Out:
#      cisp  roubo_celular
# 52     59          13788
# 57     64          10421
# 30     34           9379
# 25     29           8807
# 2       5           7992
# ..    ...            ...
# 94    111              2
# 129   155              1
# 126   152              1
# 131   157              1
# 77     92              0
#
# [138 rows x 2 columns]

# %%
#a Boa pratica sempre trabalha com esses valores de porcentagem nos quantis. Caso seja solicitado a alteração desses valores, 
#documentar de quem partiu a solicitação pois irá maquear os dados resultantes.

media = np.mean(array_roubo_celular)
mediana = np.median(array_roubo_celular)
q1 = np.quantile(array_roubo_celular, 0.25)
q2 = np.quantile(array_roubo_celular, 0.50)
q3 = np.quantile(array_roubo_celular, 0.75)

print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
